# %% [markdown]
# # Atari CrazyClimber
#
# In the Atari game CrazyClimber, the goal is to reach the top of four buildings while avoiding obstacles.

# %% [markdown]
# ## 1. Import Dependencies

# %%
# Uncomment to install required packages
# !pip install 'stable-baselines3[extra]'
# !pip install 'pyglet==1.5.27'

# %%
# Import Gymnasium and Stable Baseline modules
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env
import os

# %% [markdown]
# ## 2. Get a Feel for the Environment

# %%
# Load environment
environment_name = "ALE/CrazyClimber-v5"
env = gym.make(environment_name)
# Out:
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]

# %% [markdown]
# ## 3. Vectorise and Train Model

# %%
# load environment
env = make_atari_env(environment_name, n_envs=4, seed=0)
env = VecFrameStack(env, n_stack=4)

# %%
# establish log math and load model
log_path = os.path.join("Training", "Logs")
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
# train model, experiment with timesteps
model.learn(total_timesteps=500000)
# Out:
# Logging to Training/Logs/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.03e+03 |
# |    ep_rew_mean     | 1.07e+04 |
# | time/              |          |
# |    fps             | 621      |
# |    iterations      | 1        |
# |    time_elapsed    | 13       |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.16e+03    |
# |    ep_rew_mean          | 1.2e+04     |
# | time/                   |             |
# |    fps                  | 350         |
# |    iterations           | 2           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.017487943 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | -0.0153     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.272       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 0.748       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.97e+03    |
# |    ep_rew_mean          | 1.13e+04    |
# | time/                   |             |
# |    fps                  | 307         |
# |    iterations           | 3           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.011857493 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.369       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.467       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 1.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.98e+03    |
# |    ep_rew_mean          | 1.15e+04    |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 4           |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010884386 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.475       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.745       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 1.48        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.96e+03    |
# |    ep_rew_mean          | 1.17e+04    |
# | time/                   |             |
# |    fps                  | 278         |
# |    iterations           | 5           |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011129624 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.822       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 1.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.92e+03    |
# |    ep_rew_mean          | 1.18e+04    |
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 6           |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009705437 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.603       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.784       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00844    |
# |    value_loss           | 2.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.88e+03    |
# |    ep_rew_mean          | 1.18e+04    |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 7           |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010365704 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | 0.626       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.843       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00821    |
# |    value_loss           | 2.44        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.85e+03    |
# |    ep_rew_mean          | 1.19e+04    |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 8           |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010951884 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.746       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 2.87        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.84e+03    |
# |    ep_rew_mean          | 1.21e+04    |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 9           |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012637198 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.93        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 2.64        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.85e+03   |
# |    ep_rew_mean          | 1.27e+04   |
# | time/                   |            |
# |    fps                  | 250        |
# |    iterations           | 10         |
# |    time_elapsed         | 327        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.01175702 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.95      |
# |    explained_variance   | 0.609      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.02       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0131    |
# |    value_loss           | 2.53       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.8e+03     |
# |    ep_rew_mean          | 1.28e+04    |
# | time/                   |             |
# |    fps                  | 249         |
# |    iterations           | 11          |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.013630414 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.664       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.836       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 2.4         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.79e+03    |
# |    ep_rew_mean          | 1.31e+04    |
# | time/                   |             |
# |    fps                  | 248         |
# |    iterations           | 12          |
# |    time_elapsed         | 396         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011765283 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.771       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 3.59        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.77e+03     |
# |    ep_rew_mean          | 1.33e+04     |
# | time/                   |              |
# |    fps                  | 247          |
# |    iterations           | 13           |
# |    time_elapsed         | 430          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0135459695 |
# |    clip_fraction        | 0.179        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.64         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0132      |
# |    value_loss           | 3.18         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.75e+03    |
# |    ep_rew_mean          | 1.35e+04    |
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 14          |
# |    time_elapsed         | 465         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.014267075 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.797       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 3.31        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.75e+03    |
# |    ep_rew_mean          | 1.39e+04    |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 15          |
# |    time_elapsed         | 500         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.017475123 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.98        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 3.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.77e+03    |
# |    ep_rew_mean          | 1.44e+04    |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 16          |
# |    time_elapsed         | 534         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.015545871 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.655       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.54        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 3.57        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.84e+03    |
# |    ep_rew_mean          | 1.55e+04    |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 17          |
# |    time_elapsed         | 570         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.016611684 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.55        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 3.82        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.84e+03    |
# |    ep_rew_mean          | 1.58e+04    |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 18          |
# |    time_elapsed         | 607         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.019936651 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 3.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.84e+03    |
# |    ep_rew_mean          | 1.59e+04    |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 19          |
# |    time_elapsed         | 643         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.017766245 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.37        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 3.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.86e+03    |
# |    ep_rew_mean          | 1.64e+04    |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 20          |
# |    time_elapsed         | 681         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.018586272 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 3.43        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.87e+03    |
# |    ep_rew_mean          | 1.72e+04    |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 21          |
# |    time_elapsed         | 716         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.016395358 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.5         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 4.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.92e+03    |
# |    ep_rew_mean          | 1.82e+04    |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 22          |
# |    time_elapsed         | 751         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.016892903 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.721       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.77        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 4.56        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.93e+03    |
# |    ep_rew_mean          | 1.93e+04    |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 23          |
# |    time_elapsed         | 784         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.019450316 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 4.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.88e+03    |
# |    ep_rew_mean          | 2e+04       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 24          |
# |    time_elapsed         | 817         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.016682051 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 5.04        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.86e+03   |
# |    ep_rew_mean          | 2.06e+04   |
# | time/                   |            |
# |    fps                  | 240        |
# |    iterations           | 25         |
# |    time_elapsed         | 851        |
# |    total_timesteps      | 204800     |
# | train/                  |            |
# |    approx_kl            | 0.01820353 |
# |    clip_fraction        | 0.211      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.67      |
# |    explained_variance   | 0.741      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.37       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0126    |
# |    value_loss           | 6.55       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.8e+03     |
# |    ep_rew_mean          | 2.09e+04    |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 26          |
# |    time_elapsed         | 884         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.018732388 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.798       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 4.81        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.8e+03     |
# |    ep_rew_mean          | 2.19e+04    |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 27          |
# |    time_elapsed         | 918         |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.020997513 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 5.63        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.79e+03    |
# |    ep_rew_mean          | 2.26e+04    |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 28          |
# |    time_elapsed         | 951         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.020780835 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.71        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 6.05        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.81e+03    |
# |    ep_rew_mean          | 2.38e+04    |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 29          |
# |    time_elapsed         | 985         |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.020610627 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.1         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 5.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.79e+03    |
# |    ep_rew_mean          | 2.45e+04    |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 30          |
# |    time_elapsed         | 1019        |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.022487152 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.94        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 5.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.74e+03    |
# |    ep_rew_mean          | 2.46e+04    |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 31          |
# |    time_elapsed         | 1054        |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.021955542 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.65        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 5.7         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.8e+03    |
# |    ep_rew_mean          | 2.56e+04   |
# | time/                   |            |
# |    fps                  | 240        |
# |    iterations           | 32         |
# |    time_elapsed         | 1089       |
# |    total_timesteps      | 262144     |
# | train/                  |            |
# |    approx_kl            | 0.02190184 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.56      |
# |    explained_variance   | 0.757      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.34       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0144    |
# |    value_loss           | 6.57       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.88e+03    |
# |    ep_rew_mean          | 2.68e+04    |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 33          |
# |    time_elapsed         | 1124        |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.024722826 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.927       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 5.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.92e+03    |
# |    ep_rew_mean          | 2.75e+04    |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 34          |
# |    time_elapsed         | 1158        |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.027748115 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.5         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 4.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.96e+03    |
# |    ep_rew_mean          | 2.86e+04    |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 35          |
# |    time_elapsed         | 1194        |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.023168277 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.54        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 4.97        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.95e+03    |
# |    ep_rew_mean          | 2.87e+04    |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 36          |
# |    time_elapsed         | 1232        |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.020535668 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.9         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 6.92        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.94e+03    |
# |    ep_rew_mean          | 2.88e+04    |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 37          |
# |    time_elapsed         | 1268        |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.019811366 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.94        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 8.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.93e+03    |
# |    ep_rew_mean          | 2.9e+04     |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 38          |
# |    time_elapsed         | 1304        |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.026421746 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 7.05        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.93e+03    |
# |    ep_rew_mean          | 2.93e+04    |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 39          |
# |    time_elapsed         | 1340        |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.027282495 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.1         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 6.34        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.93e+03  |
# |    ep_rew_mean          | 2.93e+04  |
# | time/                   |           |
# |    fps                  | 237       |
# |    iterations           | 40        |
# |    time_elapsed         | 1376      |
# |    total_timesteps      | 327680    |
# | train/                  |           |
# |    approx_kl            | 0.0256274 |
# |    clip_fraction        | 0.248     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.43     |
# |    explained_variance   | 0.812     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.77      |
# |    n_updates            | 390       |
# |    policy_gradient_loss | -0.0144   |
# |    value_loss           | 7.14      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.9e+03     |
# |    ep_rew_mean          | 2.95e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 41          |
# |    time_elapsed         | 1412        |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.023220083 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.68        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 7.58        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.85e+03  |
# |    ep_rew_mean          | 2.94e+04  |
# | time/                   |           |
# |    fps                  | 237       |
# |    iterations           | 42        |
# |    time_elapsed         | 1448      |
# |    total_timesteps      | 344064    |
# | train/                  |           |
# |    approx_kl            | 0.0290531 |
# |    clip_fraction        | 0.248     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.4      |
# |    explained_variance   | 0.808     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.38      |
# |    n_updates            | 410       |
# |    policy_gradient_loss | -0.0141   |
# |    value_loss           | 7.2       |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.83e+03   |
# |    ep_rew_mean          | 2.95e+04   |
# | time/                   |            |
# |    fps                  | 237        |
# |    iterations           | 43         |
# |    time_elapsed         | 1485       |
# |    total_timesteps      | 352256     |
# | train/                  |            |
# |    approx_kl            | 0.02784454 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.826      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.45       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0121    |
# |    value_loss           | 7.2        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.86e+03    |
# |    ep_rew_mean          | 2.98e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 44          |
# |    time_elapsed         | 1518        |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.027287817 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.62        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 7.61        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.87e+03   |
# |    ep_rew_mean          | 3.04e+04   |
# | time/                   |            |
# |    fps                  | 237        |
# |    iterations           | 45         |
# |    time_elapsed         | 1552       |
# |    total_timesteps      | 368640     |
# | train/                  |            |
# |    approx_kl            | 0.02807432 |
# |    clip_fraction        | 0.266      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.816      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.69       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0138    |
# |    value_loss           | 6.56       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.85e+03    |
# |    ep_rew_mean          | 3.05e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 46          |
# |    time_elapsed         | 1586        |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.029025327 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.823       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.82        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 7.31        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.84e+03   |
# |    ep_rew_mean          | 3.02e+04   |
# | time/                   |            |
# |    fps                  | 237        |
# |    iterations           | 47         |
# |    time_elapsed         | 1619       |
# |    total_timesteps      | 385024     |
# | train/                  |            |
# |    approx_kl            | 0.02714483 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.825      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.22       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0135    |
# |    value_loss           | 7.47       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.88e+03   |
# |    ep_rew_mean          | 3.04e+04   |
# | time/                   |            |
# |    fps                  | 237        |
# |    iterations           | 48         |
# |    time_elapsed         | 1653       |
# |    total_timesteps      | 393216     |
# | train/                  |            |
# |    approx_kl            | 0.02845018 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.78       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.71       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0148    |
# |    value_loss           | 7.81       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.89e+03    |
# |    ep_rew_mean          | 3.03e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 49          |
# |    time_elapsed         | 1686        |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.027856369 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.76        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 6.76        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.9e+03     |
# |    ep_rew_mean          | 2.98e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 50          |
# |    time_elapsed         | 1721        |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.031783998 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.76        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0168     |
# |    value_loss           | 5.87        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.87e+03    |
# |    ep_rew_mean          | 2.92e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 51          |
# |    time_elapsed         | 1756        |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.024007382 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 8.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.89e+03    |
# |    ep_rew_mean          | 2.94e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 52          |
# |    time_elapsed         | 1793        |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.030757155 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.23        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 6.87        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.87e+03    |
# |    ep_rew_mean          | 2.92e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 53          |
# |    time_elapsed         | 1827        |
# |    total_timesteps      | 434176      |
# | train/                  |             |
# |    approx_kl            | 0.029699713 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.828       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.62        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 5.81        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.93e+03   |
# |    ep_rew_mean          | 3.01e+04   |
# | time/                   |            |
# |    fps                  | 237        |
# |    iterations           | 54         |
# |    time_elapsed         | 1862       |
# |    total_timesteps      | 442368     |
# | train/                  |            |
# |    approx_kl            | 0.03496547 |
# |    clip_fraction        | 0.264      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | 0.824      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.32       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.014     |
# |    value_loss           | 6.72       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.94e+03    |
# |    ep_rew_mean          | 3.06e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 55          |
# |    time_elapsed         | 1897        |
# |    total_timesteps      | 450560      |
# | train/                  |             |
# |    approx_kl            | 0.029562216 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.95        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 6.07        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.96e+03   |
# |    ep_rew_mean          | 3.1e+04    |
# | time/                   |            |
# |    fps                  | 237        |
# |    iterations           | 56         |
# |    time_elapsed         | 1931       |
# |    total_timesteps      | 458752     |
# | train/                  |            |
# |    approx_kl            | 0.02699258 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.24      |
# |    explained_variance   | 0.822      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.85       |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.0157    |
# |    value_loss           | 6.66       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.99e+03    |
# |    ep_rew_mean          | 3.19e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 57          |
# |    time_elapsed         | 1967        |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.029041622 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.82        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00836    |
# |    value_loss           | 6.43        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.99e+03    |
# |    ep_rew_mean          | 3.26e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 58          |
# |    time_elapsed         | 2002        |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.027089905 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.4         |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 6.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.99e+03    |
# |    ep_rew_mean          | 3.34e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 59          |
# |    time_elapsed         | 2037        |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.029446324 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.05        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 7.63        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.03e+03    |
# |    ep_rew_mean          | 3.43e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 60          |
# |    time_elapsed         | 2072        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.024670733 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.61        |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 7.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.98e+03    |
# |    ep_rew_mean          | 3.43e+04    |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 61          |
# |    time_elapsed         | 2107        |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.026486693 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.99        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 7.9         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.01e+03   |
# |    ep_rew_mean          | 3.49e+04   |
# | time/                   |            |
# |    fps                  | 236        |
# |    iterations           | 62         |
# |    time_elapsed         | 2143       |
# |    total_timesteps      | 507904     |
# | train/                  |            |
# |    approx_kl            | 0.02662816 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.82       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.74       |
# |    n_updates            | 610        |
# |    policy_gradient_loss | -0.0117    |
# |    value_loss           | 8.04       |
# ----------------------------------------

# %% [markdown]
# ## 4. Save and Reload Model

# %%
model_path = os.path.join("Training", "Saved Models", "PPO_CrazyClimber_500k_Model")

# %%
model.save(model_path)

# %%
del model

# %% [markdown]
# ## 5. Evaluate and Test

# %%
model_path = os.path.join("Training", "Saved Models", "PPO_CrazyClimber_500k_Model")

# %%
model = PPO.load(model_path)

# %%
env = make_atari_env(environment_name, n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=4)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /Users/alice/miniforge3/envs/spinningup/lib/python3.10/site-packages/gym/envs/atari/environment.py:267: UserWarning: WARN: We strongly suggest supplying `render_mode` when constructing your environment, e.g., gym.make(ID, render_mode='human'). Using `render_mode` provides access to proper scaling, audio support, and proper framerates.
#   logger.warn(
# (24970.0, 4771.1738597540125)

# %%
env.close()

# %%
# Manually test the model using "model.predict"
EPISODES = 5

for episode in range(1, EPISODES + 1):
    # Setup
    done = False
    score = 0
    
    # Reset environment and get initial observation
    obs = env.reset()
    
    # RL Loop
    while not done:
        # Graphical view
        env.render()
        
        # Get one random available action
        action, _ = model.predict(obs)
        
        # Take that action
        obs, reward, done, info = env.step(action)
        
        # Update score
        score += reward
        
    # Print statistics
    print(f"Episode #{episode} - Score: {score}")

# %%
env.close()
